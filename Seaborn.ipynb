# %%
# %matplotlib inline

import numpy as np;
import matplotlib.pyplot as plt;

# %%
x = np.linspace(1,10,100);

sns.set_style('ticks');

plt.plot(x, np.sin(x), c='red', ls='--');
plt.plot(x, np.cos(x), c='blue', ls='--');
plt.show();

# %%
import seaborn as sns
